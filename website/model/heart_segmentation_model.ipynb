# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline
import cv2 as cv

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf
from keras import backend as K
import keras
print(keras.__version__)

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from tensorflow.keras import layers, models, losses
from tensorflow.keras.utils import to_categorical

import tensorflow.keras
from tensorflow.keras import backend as K

print(tensorflow.__version__)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# 2.8.0
# 2.8.2

# %%
# Download the dataset

# !wget https://github.com/itsahyarr/heart-segmentation-dataset/archive/refs/heads/main.zip
# !unzip main.zip
# Out:
# --2022-06-06 14:24:05--  https://github.com/itsahyarr/heart-segmentation-dataset/archive/refs/heads/main.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/itsahyarr/heart-segmentation-dataset/zip/refs/heads/main [following]
# --2022-06-06 14:24:05--  https://codeload.github.com/itsahyarr/heart-segmentation-dataset/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [   <=>              ]   4.93M  12.0MB/s    in 0.4s
#
# 2022-06-06 14:24:06 (12.0 MB/s) - ‘main.zip’ saved [5174558]
#
# Archive:  main.zip
# bb1da2ffdcd09e063bcd5264f942ceae8249fac2
#    creating: heart-segmentation-dataset-main/
#    creating: heart-segmentation-dataset-main/Imagenes/
#   inflating: heart-segmentation-dataset-main/Imagenes/(1).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(10).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(100).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(101).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(102).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(103).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(104).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(105).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(106).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(107).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(108).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(109).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(11).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(110).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(111).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(112).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(113).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(114).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(115).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(116).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(117).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(118).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(119).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(12).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(120).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(121).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(122).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(13).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(14).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(15).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(16).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(17).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(18).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(19).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(2).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(20).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(21).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(22).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(23).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(24).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(25).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(26).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(27).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(28).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(29).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(3).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(30).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(31).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(32).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(33).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(34).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(35).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(36).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(37).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(38).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(39).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(4).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(40).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(41).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(42).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(43).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(44).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(45).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(46).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(47).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(48).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(49).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(5).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(50).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(51).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(52).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(53).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(54).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(55).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(56).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(57).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(58).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(59).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(6).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(60).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(61).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(62).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(63).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(64).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(65).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(66).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(67).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(68).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(69).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(7).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(70).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(71).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(72).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(73).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(74).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(75).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(76).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(77).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(78).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(79).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(8).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(80).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(81).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(82).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(83).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(84).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(85).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(86).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(87).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(88).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(89).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(9).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(90).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(91).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(92).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(93).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(94).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(95).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(96).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(97).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(98).tiff
#   inflating: heart-segmentation-dataset-main/Imagenes/(99).tiff
#    creating: heart-segmentation-dataset-main/VD/
#   inflating: heart-segmentation-dataset-main/VD/(1).tiff
#   inflating: heart-segmentation-dataset-main/VD/(10).tiff
#   inflating: heart-segmentation-dataset-main/VD/(100).tiff
#   inflating: heart-segmentation-dataset-main/VD/(101).tiff
#   inflating: heart-segmentation-dataset-main/VD/(102).tiff
#   inflating: heart-segmentation-dataset-main/VD/(103).tiff
#   inflating: heart-segmentation-dataset-main/VD/(104).tiff
#   inflating: heart-segmentation-dataset-main/VD/(105).tiff
#   inflating: heart-segmentation-dataset-main/VD/(106).tiff
#   inflating: heart-segmentation-dataset-main/VD/(107).tiff
#   inflating: heart-segmentation-dataset-main/VD/(108).tiff
#   inflating: heart-segmentation-dataset-main/VD/(109).tiff
#   inflating: heart-segmentation-dataset-main/VD/(11).tiff
#   inflating: heart-segmentation-dataset-main/VD/(110).tiff
#   inflating: heart-segmentation-dataset-main/VD/(111).tiff
#   inflating: heart-segmentation-dataset-main/VD/(112).tiff
#   inflating: heart-segmentation-dataset-main/VD/(113).tiff
#   inflating: heart-segmentation-dataset-main/VD/(114).tiff
#   inflating: heart-segmentation-dataset-main/VD/(115).tiff
#   inflating: heart-segmentation-dataset-main/VD/(116).tiff
#   inflating: heart-segmentation-dataset-main/VD/(117).tiff
#   inflating: heart-segmentation-dataset-main/VD/(118).tiff
#   inflating: heart-segmentation-dataset-main/VD/(119).tiff
#   inflating: heart-segmentation-dataset-main/VD/(12).tiff
#   inflating: heart-segmentation-dataset-main/VD/(120).tiff
#   inflating: heart-segmentation-dataset-main/VD/(121).tiff
#   inflating: heart-segmentation-dataset-main/VD/(122).tiff
#   inflating: heart-segmentation-dataset-main/VD/(13).tiff
#   inflating: heart-segmentation-dataset-main/VD/(14).tiff
#   inflating: heart-segmentation-dataset-main/VD/(15).tiff
#   inflating: heart-segmentation-dataset-main/VD/(16).tiff
#   inflating: heart-segmentation-dataset-main/VD/(17).tiff
#   inflating: heart-segmentation-dataset-main/VD/(18).tiff
#   inflating: heart-segmentation-dataset-main/VD/(19).tiff
#   inflating: heart-segmentation-dataset-main/VD/(2).tiff
#   inflating: heart-segmentation-dataset-main/VD/(20).tiff
#   inflating: heart-segmentation-dataset-main/VD/(21).tiff
#   inflating: heart-segmentation-dataset-main/VD/(22).tiff
#   inflating: heart-segmentation-dataset-main/VD/(23).tiff
#   inflating: heart-segmentation-dataset-main/VD/(24).tiff
#   inflating: heart-segmentation-dataset-main/VD/(25).tiff
#   inflating: heart-segmentation-dataset-main/VD/(26).tiff
#   inflating: heart-segmentation-dataset-main/VD/(27).tiff
#   inflating: heart-segmentation-dataset-main/VD/(28).tiff
#   inflating: heart-segmentation-dataset-main/VD/(29).tiff
#   inflating: heart-segmentation-dataset-main/VD/(3).tiff
#   inflating: heart-segmentation-dataset-main/VD/(30).tiff
#   inflating: heart-segmentation-dataset-main/VD/(31).tiff
#   inflating: heart-segmentation-dataset-main/VD/(32).tiff
#   inflating: heart-segmentation-dataset-main/VD/(33).tiff
#   inflating: heart-segmentation-dataset-main/VD/(34).tiff
#   inflating: heart-segmentation-dataset-main/VD/(35).tiff
#   inflating: heart-segmentation-dataset-main/VD/(36).tiff
#   inflating: heart-segmentation-dataset-main/VD/(37).tiff
#   inflating: heart-segmentation-dataset-main/VD/(38).tiff
#   inflating: heart-segmentation-dataset-main/VD/(39).tiff
#   inflating: heart-segmentation-dataset-main/VD/(4).tiff
#   inflating: heart-segmentation-dataset-main/VD/(40).tiff
#   inflating: heart-segmentation-dataset-main/VD/(41).tiff
#   inflating: heart-segmentation-dataset-main/VD/(42).tiff
#   inflating: heart-segmentation-dataset-main/VD/(43).tiff
#   inflating: heart-segmentation-dataset-main/VD/(44).tiff
#   inflating: heart-segmentation-dataset-main/VD/(45).tiff
#   inflating: heart-segmentation-dataset-main/VD/(46).tiff
#   inflating: heart-segmentation-dataset-main/VD/(47).tiff
#   inflating: heart-segmentation-dataset-main/VD/(48).tiff
#   inflating: heart-segmentation-dataset-main/VD/(49).tiff
#   inflating: heart-segmentation-dataset-main/VD/(5).tiff
#   inflating: heart-segmentation-dataset-main/VD/(50).tiff
#   inflating: heart-segmentation-dataset-main/VD/(51).tiff
#   inflating: heart-segmentation-dataset-main/VD/(52).tiff
#   inflating: heart-segmentation-dataset-main/VD/(53).tiff
#   inflating: heart-segmentation-dataset-main/VD/(54).tiff
#   inflating: heart-segmentation-dataset-main/VD/(55).tiff
#   inflating: heart-segmentation-dataset-main/VD/(56).tiff
#   inflating: heart-segmentation-dataset-main/VD/(57).tiff
#   inflating: heart-segmentation-dataset-main/VD/(58).tiff
#   inflating: heart-segmentation-dataset-main/VD/(59).tiff
#   inflating: heart-segmentation-dataset-main/VD/(6).tiff
#   inflating: heart-segmentation-dataset-main/VD/(60).tiff
#   inflating: heart-segmentation-dataset-main/VD/(61).tiff
#   inflating: heart-segmentation-dataset-main/VD/(62).tiff
#   inflating: heart-segmentation-dataset-main/VD/(63).tiff
#   inflating: heart-segmentation-dataset-main/VD/(64).tiff
#   inflating: heart-segmentation-dataset-main/VD/(65).tiff
#   inflating: heart-segmentation-dataset-main/VD/(66).tiff
#   inflating: heart-segmentation-dataset-main/VD/(67).tiff
#   inflating: heart-segmentation-dataset-main/VD/(68).tiff
#   inflating: heart-segmentation-dataset-main/VD/(69).tiff
#   inflating: heart-segmentation-dataset-main/VD/(7).tiff
#   inflating: heart-segmentation-dataset-main/VD/(70).tiff
#   inflating: heart-segmentation-dataset-main/VD/(71).tiff
#   inflating: heart-segmentation-dataset-main/VD/(72).tiff
#   inflating: heart-segmentation-dataset-main/VD/(73).tiff
#   inflating: heart-segmentation-dataset-main/VD/(74).tiff
#   inflating: heart-segmentation-dataset-main/VD/(75).tiff
#   inflating: heart-segmentation-dataset-main/VD/(76).tiff
#   inflating: heart-segmentation-dataset-main/VD/(77).tiff
#   inflating: heart-segmentation-dataset-main/VD/(78).tiff
#   inflating: heart-segmentation-dataset-main/VD/(79).tiff
#   inflating: heart-segmentation-dataset-main/VD/(8).tiff
#   inflating: heart-segmentation-dataset-main/VD/(80).tiff
#   inflating: heart-segmentation-dataset-main/VD/(81).tiff
#   inflating: heart-segmentation-dataset-main/VD/(82).tiff
#   inflating: heart-segmentation-dataset-main/VD/(83).tiff
#   inflating: heart-segmentation-dataset-main/VD/(84).tiff
#   inflating: heart-segmentation-dataset-main/VD/(85).tiff
#   inflating: heart-segmentation-dataset-main/VD/(86).tiff
#   inflating: heart-segmentation-dataset-main/VD/(87).tiff
#   inflating: heart-segmentation-dataset-main/VD/(88).tiff
#   inflating: heart-segmentation-dataset-main/VD/(89).tiff
#   inflating: heart-segmentation-dataset-main/VD/(9).tiff
#   inflating: heart-segmentation-dataset-main/VD/(90).tiff
#   inflating: heart-segmentation-dataset-main/VD/(91).tiff
#   inflating: heart-segmentation-dataset-main/VD/(92).tiff
#   inflating: heart-segmentation-dataset-main/VD/(93).tiff
#   inflating: heart-segmentation-dataset-main/VD/(94).tiff
#   inflating: heart-segmentation-dataset-main/VD/(95).tiff
#   inflating: heart-segmentation-dataset-main/VD/(96).tiff
#   inflating: heart-segmentation-dataset-main/VD/(97).tiff
#   inflating: heart-segmentation-dataset-main/VD/(98).tiff
#   inflating: heart-segmentation-dataset-main/VD/(99).tiff
#    creating: heart-segmentation-dataset-main/VI/
#   inflating: heart-segmentation-dataset-main/VI/(1).tiff
#   inflating: heart-segmentation-dataset-main/VI/(10).tiff
#   inflating: heart-segmentation-dataset-main/VI/(100).tiff
#   inflating: heart-segmentation-dataset-main/VI/(101).tiff
#   inflating: heart-segmentation-dataset-main/VI/(102).tiff
#   inflating: heart-segmentation-dataset-main/VI/(103).tiff
#   inflating: heart-segmentation-dataset-main/VI/(104).tiff
#   inflating: heart-segmentation-dataset-main/VI/(105).tiff
#   inflating: heart-segmentation-dataset-main/VI/(106).tiff
#   inflating: heart-segmentation-dataset-main/VI/(107).tiff
#   inflating: heart-segmentation-dataset-main/VI/(108).tiff
#   inflating: heart-segmentation-dataset-main/VI/(109).tiff
#   inflating: heart-segmentation-dataset-main/VI/(11).tiff
#   inflating: heart-segmentation-dataset-main/VI/(110).tiff
#   inflating: heart-segmentation-dataset-main/VI/(111).tiff
#   inflating: heart-segmentation-dataset-main/VI/(112).tiff
#   inflating: heart-segmentation-dataset-main/VI/(113).tiff
#   inflating: heart-segmentation-dataset-main/VI/(114).tiff
#   inflating: heart-segmentation-dataset-main/VI/(115).tiff
#   inflating: heart-segmentation-dataset-main/VI/(116).tiff
#   inflating: heart-segmentation-dataset-main/VI/(117).tiff
#   inflating: heart-segmentation-dataset-main/VI/(118).tiff
#   inflating: heart-segmentation-dataset-main/VI/(119).tiff
#   inflating: heart-segmentation-dataset-main/VI/(12).tiff
#   inflating: heart-segmentation-dataset-main/VI/(120).tiff
#   inflating: heart-segmentation-dataset-main/VI/(121).tiff
#   inflating: heart-segmentation-dataset-main/VI/(122).tiff
#   inflating: heart-segmentation-dataset-main/VI/(13).tiff
#   inflating: heart-segmentation-dataset-main/VI/(14).tiff
#   inflating: heart-segmentation-dataset-main/VI/(15).tiff
#   inflating: heart-segmentation-dataset-main/VI/(16).tiff
#   inflating: heart-segmentation-dataset-main/VI/(17).tiff
#   inflating: heart-segmentation-dataset-main/VI/(18).tiff
#   inflating: heart-segmentation-dataset-main/VI/(19).tiff
#   inflating: heart-segmentation-dataset-main/VI/(2).tiff
#   inflating: heart-segmentation-dataset-main/VI/(20).tiff
#   inflating: heart-segmentation-dataset-main/VI/(21).tiff
#   inflating: heart-segmentation-dataset-main/VI/(22).tiff
#   inflating: heart-segmentation-dataset-main/VI/(23).tiff
#   inflating: heart-segmentation-dataset-main/VI/(24).tiff
#   inflating: heart-segmentation-dataset-main/VI/(25).tiff
#   inflating: heart-segmentation-dataset-main/VI/(26).tiff
#   inflating: heart-segmentation-dataset-main/VI/(27).tiff
#   inflating: heart-segmentation-dataset-main/VI/(28).tiff
#   inflating: heart-segmentation-dataset-main/VI/(29).tiff
#   inflating: heart-segmentation-dataset-main/VI/(3).tiff
#   inflating: heart-segmentation-dataset-main/VI/(30).tiff
#   inflating: heart-segmentation-dataset-main/VI/(31).tiff
#   inflating: heart-segmentation-dataset-main/VI/(32).tiff
#   inflating: heart-segmentation-dataset-main/VI/(33).tiff
#   inflating: heart-segmentation-dataset-main/VI/(34).tiff
#   inflating: heart-segmentation-dataset-main/VI/(35).tiff
#   inflating: heart-segmentation-dataset-main/VI/(36).tiff
#   inflating: heart-segmentation-dataset-main/VI/(37).tiff
#   inflating: heart-segmentation-dataset-main/VI/(38).tiff
#   inflating: heart-segmentation-dataset-main/VI/(39).tiff
#   inflating: heart-segmentation-dataset-main/VI/(4).tiff
#   inflating: heart-segmentation-dataset-main/VI/(40).tiff
#   inflating: heart-segmentation-dataset-main/VI/(41).tiff
#   inflating: heart-segmentation-dataset-main/VI/(42).tiff
#   inflating: heart-segmentation-dataset-main/VI/(43).tiff
#   inflating: heart-segmentation-dataset-main/VI/(44).tiff
#   inflating: heart-segmentation-dataset-main/VI/(45).tiff
#   inflating: heart-segmentation-dataset-main/VI/(46).tiff
#   inflating: heart-segmentation-dataset-main/VI/(47).tiff
#   inflating: heart-segmentation-dataset-main/VI/(48).tiff
#   inflating: heart-segmentation-dataset-main/VI/(49).tiff
#   inflating: heart-segmentation-dataset-main/VI/(5).tiff
#   inflating: heart-segmentation-dataset-main/VI/(50).tiff
#   inflating: heart-segmentation-dataset-main/VI/(51).tiff
#   inflating: heart-segmentation-dataset-main/VI/(52).tiff
#   inflating: heart-segmentation-dataset-main/VI/(53).tiff
#   inflating: heart-segmentation-dataset-main/VI/(54).tiff
#   inflating: heart-segmentation-dataset-main/VI/(55).tiff
#   inflating: heart-segmentation-dataset-main/VI/(56).tiff
#   inflating: heart-segmentation-dataset-main/VI/(57).tiff
#   inflating: heart-segmentation-dataset-main/VI/(58).tiff
#   inflating: heart-segmentation-dataset-main/VI/(59).tiff
#   inflating: heart-segmentation-dataset-main/VI/(6).tiff
#   inflating: heart-segmentation-dataset-main/VI/(60).tiff
#   inflating: heart-segmentation-dataset-main/VI/(61).tiff
#   inflating: heart-segmentation-dataset-main/VI/(62).tiff
#   inflating: heart-segmentation-dataset-main/VI/(63).tiff
#   inflating: heart-segmentation-dataset-main/VI/(64).tiff
#   inflating: heart-segmentation-dataset-main/VI/(65).tiff
#   inflating: heart-segmentation-dataset-main/VI/(66).tiff
#   inflating: heart-segmentation-dataset-main/VI/(67).tiff
#   inflating: heart-segmentation-dataset-main/VI/(68).tiff
#   inflating: heart-segmentation-dataset-main/VI/(69).tiff
#   inflating: heart-segmentation-dataset-main/VI/(7).tiff
#   inflating: heart-segmentation-dataset-main/VI/(70).tiff
#   inflating: heart-segmentation-dataset-main/VI/(71).tiff
#   inflating: heart-segmentation-dataset-main/VI/(72).tiff
#   inflating: heart-segmentation-dataset-main/VI/(73).tiff
#   inflating: heart-segmentation-dataset-main/VI/(74).tiff
#   inflating: heart-segmentation-dataset-main/VI/(75).tiff
#   inflating: heart-segmentation-dataset-main/VI/(76).tiff
#   inflating: heart-segmentation-dataset-main/VI/(77).tiff
#   inflating: heart-segmentation-dataset-main/VI/(78).tiff
#   inflating: heart-segmentation-dataset-main/VI/(79).tiff
#   inflating: heart-segmentation-dataset-main/VI/(8).tiff
#   inflating: heart-segmentation-dataset-main/VI/(80).tiff
#   inflating: heart-segmentation-dataset-main/VI/(81).tiff
#   inflating: heart-segmentation-dataset-main/VI/(82).tiff
#   inflating: heart-segmentation-dataset-main/VI/(83).tiff
#   inflating: heart-segmentation-dataset-main/VI/(84).tiff
#   inflating: heart-segmentation-dataset-main/VI/(85).tiff
#   inflating: heart-segmentation-dataset-main/VI/(86).tiff
#   inflating: heart-segmentation-dataset-main/VI/(87).tiff
#   inflating: heart-segmentation-dataset-main/VI/(88).tiff
#   inflating: heart-segmentation-dataset-main/VI/(89).tiff
#   inflating: heart-segmentation-dataset-main/VI/(9).tiff
#   inflating: heart-segmentation-dataset-main/VI/(90).tiff
#   inflating: heart-segmentation-dataset-main/VI/(91).tiff
#   inflating: heart-segmentation-dataset-main/VI/(92).tiff
#   inflating: heart-segmentation-dataset-main/VI/(93).tiff
#   inflating: heart-segmentation-dataset-main/VI/(94).tiff
#   inflating: heart-segmentation-dataset-main/VI/(95).tiff
#   inflating: heart-segmentation-dataset-main/VI/(96).tiff
#   inflating: heart-segmentation-dataset-main/VI/(97).tiff
#   inflating: heart-segmentation-dataset-main/VI/(98).tiff
#   inflating: heart-segmentation-dataset-main/VI/(99).tiff

# %%
# !mv heart-segmentation-dataset-main Dataset
# !ls Dataset
# Out:
# Imagenes  VD  VI

# %%
# READ DIRECTORIES

Path_images = './Dataset/Imagenes/'
Path_mask_1 = './Dataset/VI/'
Path_mask_2 = './Dataset/VD/'

ids_images = sorted(os.listdir(Path_images))
ids_mask_1 = sorted(os.listdir(Path_mask_1))
ids_mask_2 = sorted(os.listdir(Path_mask_2))

print("Total of images :", len(ids_images))
print("Total of masks 1:", len(ids_mask_1))
print("Total of masks 2:", len(ids_mask_2))

Sample_image = cv.imread(Path_images + ids_images[0])
Sample_mask_1 = cv.imread(Path_mask_1 + ids_mask_1[0])
Sample_mask_2 = cv.imread(Path_mask_2 + ids_mask_2[0])

print('Sample image:',Sample_image.shape, Sample_image.min(), Sample_image.max(), 
      Sample_image.dtype)
print('Sample mask 1:',Sample_mask_1.shape, Sample_mask_1.min(), Sample_mask_1.max(),
      Sample_mask_1.dtype)
print('Sample mask 2:',Sample_mask_2.shape, Sample_mask_2.min(), Sample_mask_2.max(),
      Sample_mask_2.dtype)
print('Files images:',ids_images)
print('Files mask 1:',ids_mask_1)
print('Files mask 2:',ids_mask_2)
# Out:
# Total of images : 122
# Total of masks 1: 122
# Total of masks 2: 122
# Sample image: (256, 256, 3) 0 255 uint8
# Sample mask 1: (256, 256, 3) 0 255 uint8
# Sample mask 2: (256, 256, 3) 0 255 uint8
# Files images: ['(1).tiff', '(10).tiff', '(100).tiff', '(101).tiff', '(102).tiff', '(103).tiff', '(104).tiff', '(105).tiff', '(106).tiff', '(107).tiff', '(108).tiff', '(109).tiff', '(11).tiff', '(110).tiff', '(111).tiff', '(112).tiff', '(113).tiff', '(114).tiff', '(115).tiff', '(116).tiff', '(117).tiff', '(118).tiff', '(119).tiff', '(12).tiff', '(120).tiff', '(121).tiff', '(122).tiff', '(13).tiff', '(14).tiff', '(15).tiff', '(16).tiff', '(17).tiff', '(18).tiff', '(19).tiff', '(2).tiff', '(20).tiff', '(21).tiff', '(22).tiff', '(23).tiff', '(24).tiff', '(25).tiff', '(26).tiff', '(27).tiff', '(28).tiff', '(29).tiff', '(3).tiff', '(30).tiff', '(31).tiff', '(32).tiff', '(33).tiff', '(34).tiff', '(35).tiff', '(36).tiff', '(37).tiff', '(38).tiff', '(39).tiff', '(4).tiff', '(40).tiff', '(41).tiff', '(42).tiff', '(43).tiff', '(44).tiff', '(45).tiff', '(46).tiff', '(47).tiff', '(48).tiff', '(49).tiff', '(5).tiff', '(50).tiff', '(51).tiff', '(52).tiff', '(53).tiff', '(54).tiff', '(55).tiff', '(56).tiff', '(57).tiff', '(58).tiff', '(59).tiff', '(6).tiff', '(60).tiff', '(61).tiff', '(62).tiff', '(63).tiff', '(64).tiff', '(65).tiff', '(66).tiff', '(67).tiff', '(68).tiff', '(69).tiff', '(7).tiff', '(70).tiff', '(71).tiff', '(72).tiff', '(73).tiff', '(74).tiff', '(75).tiff', '(76).tiff', '(77).tiff', '(78).tiff', '(79).tiff', '(8).tiff', '(80).tiff', '(81).tiff', '(82).tiff', '(83).tiff', '(84).tiff', '(85).tiff', '(86).tiff', '(87).tiff', '(88).tiff', '(89).tiff', '(9).tiff', '(90).tiff', '(91).tiff', '(92).tiff', '(93).tiff', '(94).tiff', '(95).tiff', '(96).tiff', '(97).tiff', '(98).tiff', '(99).tiff']
# Files mask 1: ['(1).tiff', '(10).tiff', '(100).tiff', '(101).tiff', '(102).tiff', '(103).tiff', '(104).tiff', '(105).tiff', '(106).tiff', '(107).tiff', '(108).tiff', '(109).tiff', '(11).tiff', '(110).tiff', '(111).tiff', '(112).tiff', '(113).tiff', '(114).tiff', '(115).tiff', '(116).tiff', '(117).tiff', '(118).tiff', '(119).tiff', '(12).tiff', '(120).tiff', '(121).tiff', '(122).tiff', '(13).tiff', '(14).tiff', '(15).tiff', '(16).tiff', '(17).tiff', '(18).tiff', '(19).tiff', '(2).tiff', '(20).tiff', '(21).tiff', '(22).tiff', '(23).tiff', '(24).tiff', '(25).tiff', '(26).tiff', '(27).tiff', '(28).tiff', '(29).tiff', '(3).tiff', '(30).tiff', '(31).tiff', '(32).tiff', '(33).tiff', '(34).tiff', '(35).tiff', '(36).tiff', '(37).tiff', '(38).tiff', '(39).tiff', '(4).tiff', '(40).tiff', '(41).tiff', '(42).tiff', '(43).tiff', '(44).tiff', '(45).tiff', '(46).tiff', '(47).tiff', '(48).tiff', '(49).tiff', '(5).tiff', '(50).tiff', '(51).tiff', '(52).tiff', '(53).tiff', '(54).tiff', '(55).tiff', '(56).tiff', '(57).tiff', '(58).tiff', '(59).tiff', '(6).tiff', '(60).tiff', '(61).tiff', '(62).tiff', '(63).tiff', '(64).tiff', '(65).tiff', '(66).tiff', '(67).tiff', '(68).tiff', '(69).tiff', '(7).tiff', '(70).tiff', '(71).tiff', '(72).tiff', '(73).tiff', '(74).tiff', '(75).tiff', '(76).tiff', '(77).tiff', '(78).tiff', '(79).tiff', '(8).tiff', '(80).tiff', '(81).tiff', '(82).tiff', '(83).tiff', '(84).tiff', '(85).tiff', '(86).tiff', '(87).tiff', '(88).tiff', '(89).tiff', '(9).tiff', '(90).tiff', '(91).tiff', '(92).tiff', '(93).tiff', '(94).tiff', '(95).tiff', '(96).tiff', '(97).tiff', '(98).tiff', '(99).tiff']
# Files mask 2: ['(1).tiff', '(10).tiff', '(100).tiff', '(101).tiff', '(102).tiff', '(103).tiff', '(104).tiff', '(105).tiff', '(106).tiff', '(107).tiff', '(108).tiff', '(109).tiff', '(11).tiff', '(110).tiff', '(111).tiff', '(112).tiff', '(113).tiff', '(114).tiff', '(115).tiff', '(116).tiff', '(117).tiff', '(118).tiff', '(119).tiff', '(12).tiff', '(120).tiff', '(121).tiff', '(122).tiff', '(13).tiff', '(14).tiff', '(15).tiff', '(16).tiff', '(17).tiff', '(18).tiff', '(19).tiff', '(2).tiff', '(20).tiff', '(21).tiff', '(22).tiff', '(23).tiff', '(24).tiff', '(25).tiff', '(26).tiff', '(27).tiff', '(28).tiff', '(29).tiff', '(3).tiff', '(30).tiff', '(31).tiff', '(32).tiff', '(33).tiff', '(34).tiff', '(35).tiff', '(36).tiff', '(37).tiff', '(38).tiff', '(39).tiff', '(4).tiff', '(40).tiff', '(41).tiff', '(42).tiff', '(43).tiff', '(44).tiff', '(45).tiff', '(46).tiff', '(47).tiff', '(48).tiff', '(49).tiff', '(5).tiff', '(50).tiff', '(51).tiff', '(52).tiff', '(53).tiff', '(54).tiff', '(55).tiff', '(56).tiff', '(57).tiff', '(58).tiff', '(59).tiff', '(6).tiff', '(60).tiff', '(61).tiff', '(62).tiff', '(63).tiff', '(64).tiff', '(65).tiff', '(66).tiff', '(67).tiff', '(68).tiff', '(69).tiff', '(7).tiff', '(70).tiff', '(71).tiff', '(72).tiff', '(73).tiff', '(74).tiff', '(75).tiff', '(76).tiff', '(77).tiff', '(78).tiff', '(79).tiff', '(8).tiff', '(80).tiff', '(81).tiff', '(82).tiff', '(83).tiff', '(84).tiff', '(85).tiff', '(86).tiff', '(87).tiff', '(88).tiff', '(89).tiff', '(9).tiff', '(90).tiff', '(91).tiff', '(92).tiff', '(93).tiff', '(94).tiff', '(95).tiff', '(96).tiff', '(97).tiff', '(98).tiff', '(99).tiff']

# %%
# GENERATE MAIN TENSOR

im_width = Sample_image.shape[0]
im_height = Sample_image.shape[1]

X = np.zeros((len(ids_images), im_height, im_width, 3), dtype=np.float32)
y = np.zeros((len(ids_images), im_height, im_width, 1), dtype=np.float32)
z = np.zeros((len(ids_images), im_height, im_width, 1), dtype=np.float32)

# tqdm is used to display the progress bar
for n, id in tqdm_notebook(enumerate(zip(ids_images,ids_mask_1,ids_mask_2)), total=len(ids_images) ):

    # Load image and intensity transformation [0,1]
    x_img = cv.imread(Path_images + id[0], cv.IMREAD_GRAYSCALE)
    x_img = img_to_array(x_img)
    x_img = resize(x_img, (im_width, im_height), mode = 'constant', preserve_range = True)
    x_img = (x_img - x_img.min())/(x_img.max() - x_img.min())
    x_img = np.repeat(x_img[:, :, :], 3, axis = 2)

    # Load masks 1
    mask_1 = cv.imread(Path_mask_1 + id[1], cv.IMREAD_GRAYSCALE)
    mask_1 = img_to_array(mask_1)
    mask_1 = resize(mask_1, (im_width, im_height), mode = 'constant', preserve_range = True)
    mask_1 = (mask_1/mask_1.max())
    mask_1 = 1.*( mask_1 > 0.5 ).astype(np.uint8)

    # Load masks 2))
    mask_2 = cv.imread(Path_mask_2 + id[2], cv.IMREAD_GRAYSCALE)
    mask_2 = img_to_array(mask_2)
    mask_2 = resize(mask_2, (im_width, im_height), mode = 'constant', preserve_range = True)
    mask_2 = mask_2/mask_2.max()
    mask_2 = 2.*( mask_2 > 0.5 ).astype(np.uint8)

    # Save images and masks
    X[n] = x_img
    Sum = mask_1 + mask_2
    Sum[Sum > 2] = 0
    y[n] = Sum

print('Tensor images:',X.shape,X.min(),X.max())
print('Tensor masks:',y.shape,y.min(),y.max())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # This is added back by InteractiveShellApp.init_path()
#   0%|          | 0/122 [00:00<?, ?it/s]
# Tensor images: (122, 256, 256, 3) 0.0 1.0
# Tensor masks: (122, 256, 256, 1) 0.0 2.0

# %%
# SPLIT MAIN TENSOR IN TRAIN, VALIDATION AND TEST

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.2, random_state=0)

print('Tensor X_train:',X_train.shape,X_train.min(),X_train.max())
print('Tensor y_train:',y_train.shape,y_train.min(),y_train.max())

print('Tensor X_valid:',X_valid.shape,X_valid.min(),X_valid.max())
print('Tensor y_valid:',y_valid.shape,y_valid.min(),y_valid.max())


print('Tensor X_test:',X_test.shape,X_test.min(),X_test.max())
print('Tensor y_test:',y_test.shape,y_test.min(),y_test.max())
# Out:
# Tensor X_train: (97, 256, 256, 3) 0.0 1.0
# Tensor y_train: (97, 256, 256, 1) 0.0 2.0
# Tensor X_valid: (20, 256, 256, 3) 0.0 1.0
# Tensor y_valid: (20, 256, 256, 1) 0.0 2.0
# Tensor X_test: (5, 256, 256, 3) 0.0 1.0
# Tensor y_test: (5, 256, 256, 1) 0.0 2.0

# %%
# VISUALIZATION OF A SINGLE IMAGE IN TRAIN TENSOR

plt.figure(figsize=(20,20))

label = 1
plt.subplot(1,4,1)
a = X_train[label,:,:,0]
print('Imagen 0: ',a.shape, a.dtype, a.min(), a.max())
plt.imshow(a, cmap='gray')
plt.title("A single image")
plt.xticks([])
plt.yticks([])

plt.subplot(1,4,2)
b = y_train[label,:,:,0]
print('Both masks: ',b.shape, b.dtype, b.min(), b.max())
plt.imshow(b, cmap='gray')
plt.title("Both ventricles")
plt.xticks([])
plt.yticks([])

plt.subplot(1,4,3)
c = y_train[label,:,:,0]==1
print('Mask class 2: ',c.shape, c.dtype, c.min(), c.max())
plt.imshow(c, cmap='gray')
plt.title("Left ventricle mask")
plt.xticks([])
plt.yticks([])

plt.subplot(1,4,4)
d = y_train[label,:,:,0]==2
print('Mask class 2: ',d.shape, d.dtype, d.min(), d.max())
plt.imshow(d, cmap='gray')
plt.title("Right ventricle mask")
plt.xticks([])

plt.yticks([])

plt.show()
# Out:
# Imagen 0:  (256, 256) float32 0.0 1.0
# Both masks:  (256, 256) float32 0.0 2.0
# Mask class 2:  (256, 256) bool False True
# Mask class 2:  (256, 256) bool False True

# %%
# VISUALIZATION OF TRAIN TENSOR

def visualize(image_batch, mask_batch=None, pred_batch=None, num_samples=5):
    num_classes = mask_batch.shape[-1] if mask_batch is not None else 0
    fix, ax = plt.subplots(num_classes + 1, num_samples, figsize=(num_samples * 2, (num_classes + 1) * 2))

    for i in range(num_samples):
        ax_image = ax[0, i] if num_classes > 0 else ax[i]
        ax_image.imshow(image_batch[i,:,:,0], cmap='gray')
        ax_image.set_xticks([]) 
        ax_image.set_yticks([])
        
        if mask_batch is not None:
            for j in range(num_classes):
                if pred_batch is None:
                    mask_to_show = mask_batch[i,:,:,j]
                else:
                    mask_to_show = np.zeros(shape=(*mask_batch.shape[1:-1], 3)) 
                    mask_to_show[..., 0] = pred_batch[i,:,:,j] > 0.5
                    mask_to_show[..., 1] = mask_batch[i,:,:,j]
                ax[j + 1, i].imshow(mask_to_show, vmin=0, vmax=1)
                ax[j + 1, i].set_xticks([]) 
                ax[j + 1, i].set_yticks([]) 

    plt.tight_layout()
    plt.show()

y_train_categorical = to_categorical(y_train)
visualize(X_train[:], y_train_categorical[:])

# %%
# DEFINE FILTERS

def conv_block(input_tensor, num_filters):
  encoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same', depth_multiplier=1)(input_tensor)
  encoder = layers.BatchNormalization(axis=-1)(encoder)
  encoder = layers.Activation('relu')(encoder)
  encoder = layers.SpatialDropout2D(0.2)(encoder)
  encoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same', depth_multiplier=1)(encoder)
  encoder = layers.BatchNormalization(axis=-1)(encoder)
  encoder = layers.Activation('relu')(encoder)
  encoder = layers.SpatialDropout2D(0.2)(encoder)
  return encoder

def decoder_block(input_tensor, concat_tensor, num_filters):
  decoder = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor) #, kernel_initializer = keras.initializers.he_uniform())(input_tensor)
  decoder = layers.concatenate([concat_tensor, decoder], axis=-1)
  decoder = layers.BatchNormalization(axis=-1)(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same', depth_multiplier=1)(decoder)

  decoder = layers.BatchNormalization(axis=-1)(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.SpatialDropout2D(0.2)(decoder)
  decoder = layers.SeparableConv2D(num_filters, (3, 3), padding='same', depth_multiplier=1)(decoder)

  decoder = layers.BatchNormalization(axis=-1)(decoder)
  decoder = layers.Activation('relu')(decoder)
  decoder = layers.SpatialDropout2D(0.2)(decoder)
  return decoder

# %%
# LOAD PRETRAINED ARCHITECURE WITH WEIGHTS

Resnet = tf.keras.applications.resnet_v2.ResNet50V2(include_top=False, weights='imagenet',  
                                                    input_shape=(256,256,3), pooling=None)

encoder0 = Resnet.layers[0].output 
encoder1 = Resnet.get_layer('conv1_conv').output 
encoder2 = Resnet.get_layer('conv2_block3_1_relu').output 
encoder3 = Resnet.get_layer('conv3_block4_1_relu').output 
encoder4 = Resnet.get_layer('conv4_block6_1_relu').output 
center = Resnet.layers[-1].output
for i in range( len(Resnet.layers) ):
  Resnet.layers[i].trainable = False

decoder4 = decoder_block(center, encoder4, 256)
decoder3 = decoder_block(decoder4, encoder3, 128)
decoder2 = decoder_block(decoder3, encoder2, 128)
decoder1 = decoder_block(decoder2, encoder1, 64)
decoder0 = decoder_block(decoder1, encoder0, 32)

outputs1 = layers.Conv2D(3, (1, 1), activation = 'softmax')(decoder0)

# %%
# COMPILE MODEL AND DEFINE HYPERPARAMETERS

model = models.Model(inputs=[Resnet.input], outputs=[outputs1])

model.compile(optimizer = tf.keras.optimizers.Adam(lr=0.005), 
              loss = losses.sparse_categorical_crossentropy, 
              metrics = ['sparse_categorical_accuracy'] )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 262, 262, 3)  0           ['input_2[0][0]']
#
#  conv1_conv (Conv2D)            (None, 128, 128, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 130, 130, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 64, 64, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 64, 64, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 64, 64, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 64, 64, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 64, 64, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 64, 64, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 64, 64, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 64, 64, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 64, 64, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 64, 64, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 64, 64, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 64, 64, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 64, 64, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 64, 64, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 64, 64, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 64, 64, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 64, 64, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 66, 66, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 32, 32, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 32, 32, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 32, 32, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 32, 32, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 32, 32, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 32, 32, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 32, 32, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 32, 32, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 32, 32, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 32, 32, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 32, 32, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 32, 32, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 32, 32, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 32, 32, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 34, 34, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 16, 16, 512)  0           ['max_pooling2d_4[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 16, 16, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 16, 16, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 16, 16, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 16, 16, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 16, 16, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 16, 16, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 16, 16, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 16, 16, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 16, 16, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 16, 16, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 16, 16, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 16, 16, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 16, 16, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 16, 16, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 16, 16, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 18, 18, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 8, 8, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 8, 8, 1024)   0           ['max_pooling2d_5[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 8, 8, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 8, 8, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 8, 8, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 10, 10, 512)  0          ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 8, 8, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 8, 8, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 8, 8, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 8, 8, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 8, 8, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 8, 8, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 8, 8, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 8, 8, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 8, 8, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
# ...
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_16[0][0]']
#
#  spatial_dropout2d_10 (SpatialD  (None, 16, 16, 256)  0          ['activation_16[0][0]']
#  ropout2D)
#
#  separable_conv2d_11 (Separable  (None, 16, 16, 256)  68096      ['spatial_dropout2d_10[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 256)  1024       ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 256)  0           ['batch_normalization_17[0][0]']
#
#  spatial_dropout2d_11 (SpatialD  (None, 16, 16, 256)  0          ['activation_17[0][0]']
#  ropout2D)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 32, 32, 128)  131200     ['spatial_dropout2d_11[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 32, 32, 256)  0           ['conv3_block4_1_relu[0][0]',
#                                                                   'conv2d_transpose_6[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['concatenate_6[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 32, 32, 128)  35200      ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 128)  512        ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_19[0][0]']
#
#  spatial_dropout2d_12 (SpatialD  (None, 32, 32, 128)  0          ['activation_19[0][0]']
#  ropout2D)
#
#  separable_conv2d_13 (Separable  (None, 32, 32, 128)  17664      ['spatial_dropout2d_12[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 32, 32, 128)  512        ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_20[0][0]']
#
#  spatial_dropout2d_13 (SpatialD  (None, 32, 32, 128)  0          ['activation_20[0][0]']
#  ropout2D)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 64, 64, 128)  65664      ['spatial_dropout2d_13[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 64, 64, 192)  0           ['conv2_block3_1_relu[0][0]',
#                                                                   'conv2d_transpose_7[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 192)  768        ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 64, 64, 192)  0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 64, 64, 128)  26432      ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 64, 64, 128)  512        ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_22[0][0]']
#
#  spatial_dropout2d_14 (SpatialD  (None, 64, 64, 128)  0          ['activation_22[0][0]']
#  ropout2D)
#
#  separable_conv2d_15 (Separable  (None, 64, 64, 128)  17664      ['spatial_dropout2d_14[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 64, 64, 128)  512        ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_23[0][0]']
#
#  spatial_dropout2d_15 (SpatialD  (None, 64, 64, 128)  0          ['activation_23[0][0]']
#  ropout2D)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 128, 128, 64  32832      ['spatial_dropout2d_15[0][0]']
#  spose)                         )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 12  0           ['conv1_conv[0][0]',
#                                 8)                                'conv2d_transpose_8[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 12  512        ['concatenate_8[0][0]']
#  ormalization)                  8)
#
#  activation_24 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_24[0][0]']
#                                 8)
#
#  separable_conv2d_16 (Separable  (None, 128, 128, 64  9408       ['activation_24[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 64  256        ['separable_conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_25 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  spatial_dropout2d_16 (SpatialD  (None, 128, 128, 64  0          ['activation_25[0][0]']
#  ropout2D)                      )
#
#  separable_conv2d_17 (Separable  (None, 128, 128, 64  4736       ['spatial_dropout2d_16[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 64  256        ['separable_conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_26 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_26[0][0]']
#                                 )
#
#  spatial_dropout2d_17 (SpatialD  (None, 128, 128, 64  0          ['activation_26[0][0]']
#  ropout2D)                      )
#
#  conv2d_transpose_9 (Conv2DTran  (None, 256, 256, 32  8224       ['spatial_dropout2d_17[0][0]']
#  spose)                         )
#
#  concatenate_9 (Concatenate)    (None, 256, 256, 35  0           ['input_2[0][0]',
#                                 )                                 'conv2d_transpose_9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 35  140        ['concatenate_9[0][0]']
#  ormalization)                  )
#
#  activation_27 (Activation)     (None, 256, 256, 35  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  separable_conv2d_18 (Separable  (None, 256, 256, 32  1467       ['activation_27[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_28 (BatchN  (None, 256, 256, 32  128        ['separable_conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_28 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_28[0][0]']
#                                 )
#
#  spatial_dropout2d_18 (SpatialD  (None, 256, 256, 32  0          ['activation_28[0][0]']
#  ropout2D)                      )
#
#  separable_conv2d_19 (Separable  (None, 256, 256, 32  1344       ['spatial_dropout2d_18[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_29 (BatchN  (None, 256, 256, 32  128        ['separable_conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_29 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_29[0][0]']
#                                 )
#
#  spatial_dropout2d_19 (SpatialD  (None, 256, 256, 32  0          ['activation_29[0][0]']
#  ropout2D)                      )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 3)  99          ['spatial_dropout2d_19[0][0]']
#
# ==================================================================================================
# Total params: 26,227,530
# Trainable params: 2,658,052
# Non-trainable params: 23,569,478
# __________________________________________________________________________________________________

# %%
# MODEL TRAINING

callbacks = [
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.0001, verbose=1),
    ModelCheckpoint('model-Unet_multiclass_1.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

results = model.fit(X_train, y_train, 
                    batch_size = 4, 
                    epochs = 40, 
                    callbacks = callbacks,
                    validation_data = (X_valid, y_valid)
                    )
# Out:
# Epoch 1/40
# 25/25 [==============================] - ETA: 0s - loss: 0.3859 - sparse_categorical_accuracy: 0.8900
# Epoch 1: val_loss improved from inf to 0.62888, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 11s 226ms/step - loss: 0.3859 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.6289 - val_sparse_categorical_accuracy: 0.9590 - lr: 0.0050
# Epoch 2/40
# 25/25 [==============================] - ETA: 0s - loss: 0.1112 - sparse_categorical_accuracy: 0.9568
# Epoch 2: val_loss improved from 0.62888 to 0.39717, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 183ms/step - loss: 0.1112 - sparse_categorical_accuracy: 0.9568 - val_loss: 0.3972 - val_sparse_categorical_accuracy: 0.9590 - lr: 0.0050
# Epoch 3/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0861 - sparse_categorical_accuracy: 0.9650
# Epoch 3: val_loss improved from 0.39717 to 0.24870, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0861 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.2487 - val_sparse_categorical_accuracy: 0.9590 - lr: 0.0050
# Epoch 4/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0765 - sparse_categorical_accuracy: 0.9652
# Epoch 4: val_loss improved from 0.24870 to 0.14598, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0765 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1460 - val_sparse_categorical_accuracy: 0.9590 - lr: 0.0050
# Epoch 5/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0691 - sparse_categorical_accuracy: 0.9705
# Epoch 5: val_loss improved from 0.14598 to 0.09139, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 4s 180ms/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9705 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9591 - lr: 0.0050
# Epoch 6/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0608 - sparse_categorical_accuracy: 0.9782
# Epoch 6: val_loss improved from 0.09139 to 0.07334, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.0733 - val_sparse_categorical_accuracy: 0.9764 - lr: 0.0050
# Epoch 7/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0480 - sparse_categorical_accuracy: 0.9838
# Epoch 7: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9838 - val_loss: 0.0779 - val_sparse_categorical_accuracy: 0.9684 - lr: 0.0050
# Epoch 8/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0470 - sparse_categorical_accuracy: 0.9833
# Epoch 8: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.1069 - val_sparse_categorical_accuracy: 0.9535 - lr: 0.0050
# Epoch 9/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0438 - sparse_categorical_accuracy: 0.9844
# Epoch 9: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 160ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.7516 - val_sparse_categorical_accuracy: 0.8493 - lr: 0.0050
# Epoch 10/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0376 - sparse_categorical_accuracy: 0.9869
# Epoch 10: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0376 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.4116 - val_sparse_categorical_accuracy: 0.9065 - lr: 0.0050
# Epoch 11/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0319 - sparse_categorical_accuracy: 0.9880
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
#
# Epoch 11: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 158ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.3525 - val_sparse_categorical_accuracy: 0.9233 - lr: 0.0050
# Epoch 12/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0267 - sparse_categorical_accuracy: 0.9908
# Epoch 12: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 161ms/step - loss: 0.0267 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.1508 - val_sparse_categorical_accuracy: 0.9525 - lr: 5.0000e-04
# Epoch 13/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0259 - sparse_categorical_accuracy: 0.9911
# Epoch 13: val_loss did not improve from 0.07334
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9688 - lr: 5.0000e-04
# Epoch 14/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0276 - sparse_categorical_accuracy: 0.9901
# Epoch 14: val_loss improved from 0.07334 to 0.05047, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 182ms/step - loss: 0.0276 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0505 - val_sparse_categorical_accuracy: 0.9807 - lr: 5.0000e-04
# Epoch 15/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0282 - sparse_categorical_accuracy: 0.9894
# Epoch 15: val_loss improved from 0.05047 to 0.03294, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 187ms/step - loss: 0.0282 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.0329 - val_sparse_categorical_accuracy: 0.9874 - lr: 5.0000e-04
# Epoch 16/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0270 - sparse_categorical_accuracy: 0.9899
# Epoch 16: val_loss improved from 0.03294 to 0.02578, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0258 - val_sparse_categorical_accuracy: 0.9907 - lr: 5.0000e-04
# Epoch 17/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0256 - sparse_categorical_accuracy: 0.9906
# Epoch 17: val_loss improved from 0.02578 to 0.02363, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 4s 181ms/step - loss: 0.0256 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.0236 - val_sparse_categorical_accuracy: 0.9916 - lr: 5.0000e-04
# Epoch 18/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0257 - sparse_categorical_accuracy: 0.9904
# Epoch 18: val_loss improved from 0.02363 to 0.02292, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9904 - val_loss: 0.0229 - val_sparse_categorical_accuracy: 0.9922 - lr: 5.0000e-04
# Epoch 19/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0252 - sparse_categorical_accuracy: 0.9909
# Epoch 19: val_loss improved from 0.02292 to 0.02259, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 186ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9922 - lr: 5.0000e-04
# Epoch 20/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0270 - sparse_categorical_accuracy: 0.9897
# Epoch 20: val_loss improved from 0.02259 to 0.02240, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 188ms/step - loss: 0.0270 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9922 - lr: 5.0000e-04
# Epoch 21/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0235 - sparse_categorical_accuracy: 0.9918
# Epoch 21: val_loss improved from 0.02240 to 0.02227, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 183ms/step - loss: 0.0235 - sparse_categorical_accuracy: 0.9918 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9923 - lr: 5.0000e-04
# Epoch 22/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0238 - sparse_categorical_accuracy: 0.9910
# Epoch 22: val_loss improved from 0.02227 to 0.02200, saving model to model-Unet_multiclass_1.h5
# 25/25 [==============================] - 5s 189ms/step - loss: 0.0238 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0220 - val_sparse_categorical_accuracy: 0.9924 - lr: 5.0000e-04
# Epoch 23/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0227 - sparse_categorical_accuracy: 0.9919
# Epoch 23: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0227 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0221 - val_sparse_categorical_accuracy: 0.9924 - lr: 5.0000e-04
# Epoch 24/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0221 - sparse_categorical_accuracy: 0.9921
# Epoch 24: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 162ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0222 - val_sparse_categorical_accuracy: 0.9925 - lr: 5.0000e-04
# Epoch 25/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0222 - sparse_categorical_accuracy: 0.9916
# Epoch 25: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 163ms/step - loss: 0.0222 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0231 - val_sparse_categorical_accuracy: 0.9924 - lr: 5.0000e-04
# Epoch 26/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0233 - sparse_categorical_accuracy: 0.9905
# Epoch 26: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0233 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.0228 - val_sparse_categorical_accuracy: 0.9925 - lr: 5.0000e-04
# Epoch 27/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0221 - sparse_categorical_accuracy: 0.9924
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 27: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 172ms/step - loss: 0.0221 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9926 - lr: 5.0000e-04
# Epoch 28/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0233 - sparse_categorical_accuracy: 0.9912
# Epoch 28: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0233 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9926 - lr: 1.0000e-04
# Epoch 29/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0252 - sparse_categorical_accuracy: 0.9897
# Epoch 29: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9926 - lr: 1.0000e-04
# Epoch 30/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0210 - sparse_categorical_accuracy: 0.9923
# Epoch 30: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0210 - sparse_categorical_accuracy: 0.9923 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 31/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0237 - sparse_categorical_accuracy: 0.9910
# Epoch 31: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0237 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 32/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0233 - sparse_categorical_accuracy: 0.9919
# Epoch 32: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 171ms/step - loss: 0.0233 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 33/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0224 - sparse_categorical_accuracy: 0.9921
# Epoch 33: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 34/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0217 - sparse_categorical_accuracy: 0.9916
# Epoch 34: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 166ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 35/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0217 - sparse_categorical_accuracy: 0.9920
# Epoch 35: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0217 - sparse_categorical_accuracy: 0.9920 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 36/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0215 - sparse_categorical_accuracy: 0.9925
# Epoch 36: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 164ms/step - loss: 0.0215 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0223 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 37/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0211 - sparse_categorical_accuracy: 0.9932
# Epoch 37: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 165ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.0224 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 38/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0216 - sparse_categorical_accuracy: 0.9915
# Epoch 38: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 169ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9915 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 39/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0230 - sparse_categorical_accuracy: 0.9908
# Epoch 39: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 170ms/step - loss: 0.0230 - sparse_categorical_accuracy: 0.9908 - val_loss: 0.0225 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04
# Epoch 40/40
# 25/25 [==============================] - ETA: 0s - loss: 0.0216 - sparse_categorical_accuracy: 0.9919
# Epoch 40: val_loss did not improve from 0.02200
# 25/25 [==============================] - 4s 163ms/step - loss: 0.0216 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0226 - val_sparse_categorical_accuracy: 0.9927 - lr: 1.0000e-04

# %%
## Saving model ##

# Serialize model to json
model_json = model.to_json()
with open("heart_segmentation.json", "w") as json_file:
  json_file.write(model_json)

# Serialize weights to HDF5
model.save_weights("heart_segmentation.h5")

# %%
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.title("Learning curve")
plt.plot(results.history["loss"], label="train_loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend();

plt.subplot(1,2,2)
plt.title("Learning curve")
plt.plot(results.history['sparse_categorical_accuracy'], label='train_accuracy')
plt.plot(results.history['val_sparse_categorical_accuracy'], label= 'val_accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend();

# %%
# EVALUATE VALIDATION SET (Must be equals to the best Loss)

model.evaluate(X_valid, y_valid, verbose=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 0.0226 - sparse_categorical_accuracy: 0.9927
# [0.022570906206965446, 0.9927169680595398]

# %%
# PREDICT TEST SET

predicted_label = model.predict(X_test)
print('Predicted label shape: ',predicted_label.shape, predicted_label.dtype, predicted_label.min(), predicted_label.max())
predicted_mask = to_categorical(np.argmax(predicted_label, -1), dtype='uint8')
print('Predicted mask shape: ',predicted_mask.shape, predicted_mask.dtype, predicted_mask.min(), predicted_mask.max())
print('y_test shape: ',y_test.shape, y_test.dtype, y_test.min(), y_test.max())
# Out:
# Predicted label shape:  (5, 256, 256, 3) float32 5.119011e-07 0.99999774
# Predicted mask shape:  (5, 256, 256, 3) uint8 0 1
# y_test shape:  (5, 256, 256, 1) float32 0.0 2.0

# %%
# COMPUTING DICE METRIC ON PREDICTED SET

def dice_coeff(y_true, y_pred):

  Dice_class_1 = np.zeros(y_true.shape[0])
  Dice_class_2 = np.zeros(y_true.shape[0])

  for k in range(y_true.shape[0]):

    img1 = np.asarray(y_true[k,:,:,0]==1).astype(np.bool)
    img2 = np.asarray(y_pred[k,:,:,1]).astype(np.bool)
    if img1.sum() + img2.sum() == 0: return 1
    intersection = np.logical_and(img1, img2)
    Dice_class_1[k] = 2. * intersection.sum() / (img1.sum() + img2.sum())

    img3 = np.asarray(y_true[k,:,:,0]==2).astype(np.bool)
    img4 = np.asarray(y_pred[k,:,:,2]).astype(np.bool)
    if img3.sum() + img4.sum() == 0: return 1
    intersection = np.logical_and(img3, img4)
    Dice_class_2[k] = 2. * intersection.sum() / (img3.sum() + img4.sum())

  return Dice_class_1, Dice_class_2

Dice_class_1 , Dice_class_2 = dice_coeff(y_test,predicted_mask)

print('Shape of true labels:',y_test.shape,y_test.min(),y_test.max())
print('Shape of predicted labels:',predicted_mask.shape,predicted_mask.min(),predicted_mask.max())

print('Dice mean class 1:',Dice_class_1.mean())
print('Dice per image_class_1:',Dice_class_1)

print('Dice mean class 2:',Dice_class_2.mean())
print('Dice per image_class_2:',Dice_class_2)
# Out:
# Shape of true labels: (5, 256, 256, 1) 0.0 2.0
# Shape of predicted labels: (5, 256, 256, 3) 0 1
# Dice mean class 1: 0.9640143648371311
# Dice per image_class_1: [0.97855946 0.95718475 0.97861139 0.93058918 0.97512704]
# Dice mean class 2: 0.8927328599424845
# Dice per image_class_2: [0.94289855 0.81864989 0.93639847 0.86156568 0.90415172]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
# CONFUSION MATRIX PLOT

def plot_confusion_matrix_own(cm,
                              target_names,
                              title = 'Confusion matrix',
                              cmap = None,
                              normalize = False):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    

#%% CONFUSION MATRIX

from sklearn.metrics import multilabel_confusion_matrix, ConfusionMatrixDisplay, confusion_matrix, plot_confusion_matrix

y_test_flat = y_test.ravel()

predicted_label_flat = np.argmax(predicted_label, -1).ravel().astype('float32')

cm  = confusion_matrix(y_test_flat , predicted_label_flat)
cm_norm = cm / np.sum(cm , axis = 1)[:, np.newaxis]

plot_confusion_matrix_own( cm_norm , 
                           target_names = ["Background","Left V","Right V"], 
                           title = 'Normalized confusion matrix')  
plt.show()

# %%
# COMPARISON OF A SINGLE IMAGE

plt.figure(figsize=(15,15))

label = 0
plt.subplot(1,3,1)
a = X_test[label,:,:,0]
print('Imagen: ',a.shape, a.dtype, a.min(), a.max())
plt.imshow(a, cmap='gray')
plt.title("Image")
plt.xticks([])
plt.yticks([])

plt.subplot(1,3,2)
b = y_test[label,:,:,0]
print('True mask: ',b.shape, b.dtype, b.min(), b.max())
plt.imshow(b, cmap='gray')
plt.title("Both left and right ventricle annotations")
plt.xticks([])
plt.yticks([])

plt.subplot(1,3,3)
c = predicted_mask[label,:,:,1] + 2.*(predicted_mask[label,:,:,2])
print('Predicted mask: ',c.shape, c.dtype, c.min(), c.max())
plt.imshow(c, cmap='gray')
plt.title("Both left and right ventricle segmentations")
plt.xticks([])
plt.yticks([])

plt.show()
# Out:
# Imagen:  (256, 256) float32 0.0 1.0
# True mask:  (256, 256) float32 0.0 2.0
# Predicted mask:  (256, 256) float64 0.0 2.0

# %%
# OVERLAPED COLOR PLOT

def mask_color_img(img, mask_1, color_1, mask_2, color_2, alpha=0.3):
    '''
    img: cv2 image
    mask: bool or np.where
    color: BGR triplet [_, _, _]. Default: [0, 255, 255] is yellow.
    alpha: float [0, 1]. 

    Ref: http://www.pyimagesearch.com/2016/03/07/transparent-overlays-with-opencv/
    '''
    out = img.copy()
    img_layer = img.copy()
    img_layer[mask_1] = color_1
    out = cv.addWeighted(img_layer, alpha, out, 1 - alpha, 0, out)

    out[mask_2] = color_2
    out2 = cv.addWeighted(out, alpha, out, 1 - alpha, 0, out)

    return out2


label = 2
a = X_test[label,:,:,0]
Image_rgb = np.repeat(a[:, :, np.newaxis], 3, axis=2)

true_class_1 = y_test[label,:,:,0]==1
true_class_2 = y_test[label,:,:,0]==2

True_mask = mask_color_img(Image_rgb,true_class_1,[0,255,255],
                           true_class_2,[100,0,200],alpha = 0.001)


predicted_class_1 = predicted_mask[label,:,:,1]==1
predicted_class_2 = predicted_mask[label,:,:,2]==1

Predicted_mask = mask_color_img(Image_rgb,predicted_class_1,[0,255,255],
                                predicted_class_2,[100,0,200],alpha = 0.001)


plt.figure(figsize=(15,15))

plt.subplot(1,2,1)
plt.imshow(True_mask)
plt.title("True mask")
plt.xticks([])
plt.yticks([])

plt.subplot(1,2,2)
plt.imshow(Predicted_mask)
plt.title("Predicted mask")
plt.xticks([])
plt.yticks([])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ([], <a list of 0 Text major ticklabel objects>)

# %%
# VISUALIZATION OF PREDICTIONS OF TEST SET

y_test_categorical = to_categorical(y_test)
visualize(X_test, y_test_categorical)

visualize(X_test , predicted_mask)

# %%
print(predicted_mask.shape)
visualize(predicted_mask)
# Out:
# (5, 256, 256, 3)

# %%
print(X_test.shape)
visualize(X_test)
# Out:
# (5, 256, 256, 3)

# %%
#show the mask and the segmented image

msk  = predicted_mask.squeeze()
msk[msk >= 0.5] = 1 
msk[msk < 0.5] = 0
for i in range(len(X_test)):
    combined = np.concatenate((X_test[i] ,msk[i], X_test[i]*msk[i] ), axis = 1)
    plt.axis('off')
    plt.imshow(combined)
    plt.show()
